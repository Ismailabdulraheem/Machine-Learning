# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (4.4 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /opt/miniconda3/envs/anaconda-finance/lib/python3.11/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /opt/miniconda3/envs/anaconda-finance/lib/python3.11/site-packages (from tensorflow) (6.32.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/miniconda3/envs/anaconda-finance/lib/python3.11/site-packages (from tensorflow) (2.26.0)
# Requirement already satisfied: setuptools in /opt/miniconda3/envs/anaconda-finance/lib/python3.11/site-packages (from tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in /opt/miniconda3/envs/anaconda-finance/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in /opt/miniconda3/envs/anaconda-finance/lib/python3.11/site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.1.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.78.0-cp311-cp311-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Collecting keras>=3.12.0 (from tensorflow)
#   Using cached keras-3.13.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in /opt/miniconda3/envs/anaconda-finance/lib/python3.11/site-packages (from tensorflow) (2.3.3)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.4-cp311-cp311-macosx_10_9_universal2.whl.metadata (8.9 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/miniconda3/envs/anaconda-finance/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/anaconda-finance/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/miniconda3/envs/anaconda-finance/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/anaconda-finance/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/miniconda3/envs/anaconda-finance/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Collecting rich (from keras>=3.12.0->tensorflow)
#   Using cached rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.12.0->tensorflow)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.12.0->tensorflow)
#   Downloading optree-0.19.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (34 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.12.0->tensorflow)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/miniconda3/envs/anaconda-finance/lib/python3.11/site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.21.0-cp311-cp311-macosx_12_0_arm64.whl (223.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.4/223.4 MB 1.0 MB/s  0:02:10m0:00:01m00:07
# Downloading grpcio-1.78.0-cp311-cp311-macosx_11_0_universal2.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 5.9 MB/s  0:00:01 eta 0:00:01
# Downloading h5py-3.14.0-cp311-cp311-macosx_11_0_arm64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 5.8 MB/s  0:00:00 eta 0:00:01
# Downloading ml_dtypes-0.5.4-cp311-cp311-macosx_10_9_universal2.whl (679 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 5.0 MB/s  0:00:00
# Using cached absl_py-2.4.0-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached keras-3.13.2-py3-none-any.whl (1.5 MB)
# Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-2.1.2-cp311-cp311-macosx_11_0_arm64.whl (61 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.19.0-cp311-cp311-macosx_11_0_arm64.whl (378 kB)
# Using cached rich-14.3.3-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, termcolor, optree, opt_einsum, ml_dtypes, mdurl, h5py, grpcio, google_pasta, gast, astunparse, absl-py, markdown-it-py, rich, keras, tensorflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19/19 [tensorflow]9 [tensorflow]-py]
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.78.0 h5py-3.14.0 keras-3.13.2 libclang-18.1.1 markdown-it-py-4.0.0 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.0 rich-14.3.3 tensorflow-2.21.0 termcolor-3.3.0 wrapt-2.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, Flatten, Dropout
from tensorflow.keras import Sequential
from tensorflow.keras.losses import MeanSquaredError, BinaryCrossentropy
from tensorflow.keras.activations import sigmoid
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 import tensorflow as tf
#       4 from tensorflow.keras.layers import Dense, Input, Flatten, Dropout
#       5 from tensorflow.keras import Sequential
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
mnist = tf.keras.datasets.mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train.shape
X_train[0]

# %%
X_train, X_test = X_train / 255.0, X_test / 255.0
X_train[0]

# %%
model = Sequential()
model.add(Input((28,28)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10))

nonsense_prediction = model(X_train[:1]).numpy
nonsense_prediction

# %%
# UNQ_C1
# GRADED FUNCTION: compute_entropy

def compute_entropy(y):
    """
    Computes the entropy for 
    
    Args:
       y (ndarray): Numpy array indicating whether each example at a node is
           edible (`1`) or poisonous (`0`)
       
    Returns:
        entropy (float): Entropy at that node
        
    """
    # You need to return the following variables correctly
    entropy = 0.
    
    if len(y) != 0:
     # Your code here to calculate the fraction of edible examples (i.e with value = 1 in y)
     p1 = len(y[y == 1]) / len(y)

     # For p1 = 0 and 1, set the entropy to 0 (to handle 0log0)
     if p1 != 0 and p1 != 1:
         # Your code here to calculate the entropy using the formula provided above
         entropy = -p1 * np.log2(p1) - (1 - p1) * np.log2(1 - p1)
     else:
         entropy = 0. 
 ### END CODE HERE ###    
    
    return entropy

# %%
# UNQ_C2
# GRADED FUNCTION: split_dataset

def split_dataset(X, node_indices, feature):
    """
    Splits the data at the given node into
    left and right branches
    
    Args:
        X (ndarray):             Data matrix of shape(n_samples, n_features)
        node_indices (list):     List containing the active indices. I.e, the samples being considered at this step.
        feature (int):           Index of feature to split on
    
    Returns:
        left_indices (list):     Indices with feature value == 1
        right_indices (list):    Indices with feature value == 0
    """
    
    # You need to return the following variables correctly
    left_indices = []
    right_indices = []
    
    ### START CODE HERE ###
    for i in node_indices:
        if X[i][feature] == 1:
            left_indices.append(i)
        else:
            right_indices.append(i)
    ### END CODE HERE ###
        
    return left_indices, right_indices

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from sklearn.neighbors import KNeighborsClassifier
# ----> 2 from sklearn.module import model
#
# ModuleNotFoundError: No module named 'sklearn.module'
